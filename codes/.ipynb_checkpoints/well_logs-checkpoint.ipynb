# %%
import las2 as las
import numpy as np
import matplotlib.pyplot as plt

# %%
well_path = "../data/7-MP-28D-BA.las"
#data1 = las.read(well_path)

# %%
well_28D = np.loadtxt(well_path, usecols=(0,2,3,4,5,6,7,8,9,10), skiprows=58).T
#0 = Depth
#1 = DRDN
#2 = Lith_new
#3 = BS
#4 = GR
#5 = CAl
#6 = RT
#7 = NPHI
#8 = RHOB
#9 = DT
well_28D[1]
# Out:
# array([-999., -999., -999., ..., -999., -999., -999.])

# %%
well_28D[3]
# Out:
# array([-999. , -999. , -999. , ...,    8.5,    8.5,    8.5])

# %%
for j in range(np.shape(well_28D)[0]):
    for i in range(np.shape(well_28D)[1]):
        if well_28D[j][i] == -999.000:
            well_28D[j][i] = np.nan

# %%
### Graficos

fig, (ax1, ax2) = plt.subplots(1,2) # 4 cruvas = 4 subplots
fig.set_size_inches(12, 11) # tamanho da figura | polegadas

#_____________________________________________________#

ax1.plot(well_28D[4],well_28D[0],'-g',linewidth = 1,label='GR')
# (eixo x, eixo y, cor e tipo, comprimento da curva, legenda )
ax1.plot(well_28D[3],well_28D[0],'-k',linewidth = 1,label='BS')
ax1.plot(well_28D[5],well_28D[0],'-k',linewidth = 1,label='CAL')
ax1.invert_yaxis()
# inverte o eixo y
ax1.grid()
# adiciona o 'grid' ou malha de fundo
ax1.set_ylabel('Profundidade ($m$)', fontsize=16)
# o que vai ser escrito no eixo y
ax1.set_title('GR / BS / CAL', fontsize=16)
# titulo do 'track' ou do grafico com tamanho de letra 16
ax1.legend()

#_____________________________________________________#

ax2.plot(well_28D[7],well_28D[0],'-b',linewidth = 1,label='NPHI')
ax2.plot(well_28D[8],well_28D[0],'-r',linewidth = 1,label='RHOB')
ax2.invert_yaxis()
ax2.grid()
ax2.set_title('RHOB / NPHI', fontsize=16)
ax2.legend()
#_____________________________________________________#

#ax3.plot(NPHI_DP1,prof_DP1,'-k',linewidth = 1,label='NPHI')
#ax3.invert_yaxis()
#ax3.grid()
#ax3.set_title('NPHI', fontsize=16)

#_____________________________________________________#

#ax4.plot(VSH_GR_DP1,prof_DP1,'-g',linewidth = 1,label='VSH_GR')
#ax4.plot(VSH_ND_DP1,prof_DP1,'-b',linewidth = 1,label='VSH_NR')
#ax4.invert_yaxis()
#ax4.grid()
#ax4.set_title('VSH', fontsize=16)
#ax4.legend(loc=2)
# adiciona a posicao da legenda

plt.show()

# %%
def logs(path, rows):
    name = np.loadtxt(path, skiprows=rows).T
    return name

# %%
well_31D = logs("../data/7-MP-28D-BA.las", 58)

# %%
print(well_31D[0])
# Out:
# [-4.5720000e-01 -3.0480000e-01 -1.5240000e-01 ...  3.5643312e+03
#   3.5644836e+03  3.5646360e+03]
